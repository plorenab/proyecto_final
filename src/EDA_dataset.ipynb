# %% [markdown]
# 70 273 filas
#
# unidad de análisis: especie × localización
#
# **features clave:**
#
# log_mp_particles_ml → exposición
#
# distance_km → atenuación espacial
#
# log_toxic_pressure → toxicidad relativa
#
# vuln → vulnerabilidad biológica
#
# **targets**:
#
# eco_risk_index (0–100, continuo)
#
# eco_risk_class (low / medium / high)

# %%
import pandas as pd
df = pd.read_parquet("../data/dataset.parquet")
df
# Out:
#        iucn_id                  sci_name  vuln  log_mp_particles_ml  \
# 26165    26165   Chlorogomphus caloptera     1            -5.920996
# 26166    26166   Chlorogomphus caloptera     1            -5.241001
# 26167    26167   Chlorogomphus caloptera     1            -6.502277
# 28169    28169          Coeliccia mattii     2            -5.883425
# 28088    28088  Sundaeschna cattienensis     3            -4.782695
# ...        ...                       ...   ...                  ...
# 21288    21288     Desmophyllum pertusum     2           -12.000000
# 21287    21287     Desmophyllum pertusum     2           -12.000000
# 21286    21286     Desmophyllum pertusum     2           -12.000000
# 21285    21285     Desmophyllum pertusum     2           -12.000000
# 21332    21332     Desmophyllum pertusum     2           -12.000000
#
#        distance_km  log_toxic_pressure  eco_risk_score  eco_risk_index  \
# 26165   629.473690           -7.716876       -7.716876       90.317390
# 26166   551.186292           -7.036881       -7.036881       91.611255
# 26167   696.396279           -8.298157       -8.298157       89.211354
# 28169   625.148155           -7.679305      -15.358610       75.777044
# 28088   498.421862           -6.578575      -19.735724       67.448468
# ...            ...                 ...             ...             ...
# 21288    10.135191          -13.795880      -27.591760       52.500357
# 21287    10.110293          -13.795880      -27.591760       52.500357
# 21286    10.101580          -13.795880      -27.591760       52.500357
# 21285    10.128764          -13.795880      -27.591760       52.500357
# 21332    22.853377          -13.795880      -27.591760       52.500357
#
#       eco_risk_class                                           geometry
# 26165           high  b'\x01\x01\x00\x00\x005C\xd6"b\x06gA\r}\x0f^\x...
# 26166           high  b'\x01\x01\x00\x00\x00r_5\x12\x10\xdffA\xb8\x9...
# 26167           high  b'\x01\x01\x00\x00\x00:\x17\xd4\n\xa6&gA\x9f6\...
# 28169         medium  b'\x01\x01\x00\x00\x00\xd2~\x00\x05I\x04gA\xb9...
# 28088         medium  b'\x01\x01\x00\x00\x00\x88\xfc\xb0y\xf7\xc3fA!...
# ...              ...                                                ...
# 21288         medium  b'\x01\x01\x00\x00\x00[L\xbb\xe5a\xed`\xc14\xa...
# 21287         medium  b'\x01\x01\x00\x00\x00[L\xbb\xe5a\xed`\xc1hC\x...
# 21286         medium  b'\x01\x01\x00\x00\x00[L\xbb\xe5a\xed`\xc1\xa2...
# 21285         medium  b'\x01\x01\x00\x00\x00I\x97Z\tb\xed`\xc1\x93%5...
# 21332         medium  b'\x01\x01\x00\x00\x00\xa9s\xff\xcc\x1b\xea`\x...
#
# [70273 rows x 10 columns]

# %%
df.shape
# Out:
# (70273, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70273 entries, 26165 to 21332
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   iucn_id              70273 non-null  int64
#  1   sci_name             70273 non-null  object
#  2   vuln                 70273 non-null  int64
#  3   log_mp_particles_ml  70273 non-null  float64
#  4   distance_km          70273 non-null  float64
#  5   log_toxic_pressure   70273 non-null  float64
#  6   eco_risk_score       70273 non-null  float64
#  7   eco_risk_index       70273 non-null  float64
#  8   eco_risk_class       70273 non-null  object
#  9   geometry             70273 non-null  object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 5.9+ MB

# %% [markdown]
# DISTRIBUCIÓN DE LAS VARIABLES

# %%
df.describe()
# Out:
#            iucn_id          vuln  log_mp_particles_ml   distance_km  \
# count  70273.00000  70273.000000         70273.000000  70273.000000
# mean   35136.00000      1.583723            -9.788672    250.794681
# std    20286.21207      0.777699             2.226631    302.824466
# min        0.00000      1.000000           -12.000000      0.045987
# 25%    17568.00000      1.000000           -12.000000     85.596862
# 50%    35136.00000      1.000000            -9.799003    176.394636
# 75%    52704.00000      2.000000            -8.441049    277.765575
# max    70272.00000      4.000000            -0.724252   4577.435697
#
#        log_toxic_pressure  eco_risk_score  eco_risk_index
# count        70273.000000    70273.000000    70273.000000
# mean           -11.584552      -18.474091       69.849047
# std              2.226631       10.063624       19.148611
# min            -13.795880      -55.183520        0.000000
# 25%            -13.795880      -27.591760       52.500357
# 50%            -11.594883      -13.795880       78.750535
# 75%            -10.236930      -10.936872       84.190528
# max             -2.520132       -2.628144      100.000000

# %%
import matplotlib.pyplot as plt

df["eco_risk_index"].hist(bins=50)
plt.title("Distribución del índice de riesgo ecológico")
plt.show()

# %%
import matplotlib.pyplot as plt

df["log_mp_particles_ml"].hist(bins=50)
plt.title("Distribución de la concentración de microplásticos")
plt.show()

# %%
import matplotlib.pyplot as plt

df["distance_km"].hist(bins=50)
plt.title("Distribución de la distancia")
plt.show()

# %%
df["log_toxic_pressure"].hist(bins=50)
plt.title("Distribución de la presión")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x="vuln",
    y="eco_risk_index",
    data=df
)
plt.show()

# %%
plt.scatter(
    df["log_mp_particles_ml"],
    df["eco_risk_index"],
    alpha=0.2
)
plt.xlabel("Exposición (log)")
plt.ylabel("Riesgo ecológico")
plt.show()
