# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Point, box

# %%
# Usar el mismo "idioma espacial"
CRS = "EPSG:4326"
# Elegir el tamaño de la grilla
GRID_SIZE = 0.5
# Dónde construir la grilla
noaa = gpd.read_file("../data/GeoDataFrame/gdf_microplastics.gpkg").to_crs(CRS)

# %%
minx, miny, maxx, maxy = noaa.total_bounds

# %%
buffer = 1.0
minx -= buffer
miny -= buffer
maxx += buffer
maxy += buffer

# %%
xs = np.arange(minx, maxx, GRID_SIZE)
ys = np.arange(miny, maxy, GRID_SIZE)

# %%
polygons = []
grid_ids = []

for i, x in enumerate(xs):
    for j, y in enumerate(ys):
        polygons.append(box(x, y, x + GRID_SIZE, y + GRID_SIZE))
        grid_ids.append(f"cell_{i}_{j}")

# %%
grid = gpd.GeoDataFrame(
    {"grid_id": grid_ids},
    geometry=polygons,
    crs=CRS
)

# %%
grid["lon_center"] = grid.geometry.centroid.x
grid["lat_center"] = grid.geometry.centroid.y
# Out:
# /tmp/ipykernel_74923/1856495670.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid["lon_center"] = grid.geometry.centroid.x
# /tmp/ipykernel_74923/1856495670.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   grid["lat_center"] = grid.geometry.centroid.y

# %%
noaa_joined = gpd.sjoin(
    noaa,
    grid,
    how="left",
    predicate="within"
)

# %%
noaa_features = (
    noaa_joined
    .groupby("grid_id")
    .agg(
        mp_mean_concentration=("microplastics_measurement", "mean"),
        mp_max_concentration=("microplastics_measurement", "max"),
        mp_count=("microplastics_measurement", "count")
        #mp_types_count=("plastic_type", "nunique")
    )
    .reset_index()
)

# %%
grid = grid.merge(noaa_features, on="grid_id", how="left")

# %%
iucn = gpd.read_file("../data/GeoDataFrame/gdf_species.gpkg").to_crs(CRS)

# %%
iucn_joined = gpd.overlay(iucn, grid, how="intersection")

# %%
iucn_joined.columns
# Out:
# Index(['sci_name', 'presence', 'origin', 'seasonal', 'lon', 'lat',
#        'redlistCategory', 'grid_id', 'lon_center', 'lat_center',
#        'mp_mean_concentration', 'mp_max_concentration', 'mp_count',
#        'geometry'],
#       dtype='object')

# %%
status_map = {"CR":4, "EN":3, "VU":2, "NT":1}
iucn_joined["vuln_score"] = iucn_joined["redlistCategory"].map(status_map)

# %%
iucn_features = (
    iucn_joined
    .groupby("grid_id")
    .agg(
        iucn_species_count=("sci_name", "nunique"),
        iucn_vulnerability_index=("vuln_score", "mean")
    )
    .reset_index()
)

# %%
grid = grid.merge(iucn_features, on="grid_id", how="left")

# %%
ecotaxa = pd.read_csv("../data/metadata_img.csv")
ecotaxa["geometry"] = gpd.points_from_xy(ecotaxa.object_lon, ecotaxa.object_lat)
ecotaxa = gpd.GeoDataFrame(ecotaxa, crs=CRS)
# Out:
# /tmp/ipykernel_74923/829991026.py:1: DtypeWarning: Columns (102,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   ecotaxa = pd.read_csv("../data/metadata_img.csv")

# %%
ecotaxa_joined = gpd.sjoin(ecotaxa, grid, predicate="within")

# %%
ecotaxa_features = (
    ecotaxa_joined
    .groupby("grid_id")
    .agg(
        mean_particle_size=("object_area","mean"),
        small_particle_ratio=("object_area", lambda x: (x<100).mean())
    )
    .reset_index()
)

# %%
grid = grid.merge(ecotaxa_features, on="grid_id", how="left")

# %%
grid
# Out:
#              grid_id                                           geometry  \
# 0           cell_0_0  POLYGON ((-180.4942 -72.69904, -180.4942 -72.1...
# 1           cell_0_1  POLYGON ((-180.4942 -72.19904, -180.4942 -71.6...
# 2           cell_0_2  POLYGON ((-180.4942 -71.69904, -180.4942 -71.1...
# 3           cell_0_3  POLYGON ((-180.4942 -71.19904, -180.4942 -70.6...
# 4           cell_0_4  POLYGON ((-180.4942 -70.69904, -180.4942 -70.1...
# ...              ...                                                ...
# 236743  cell_723_322  POLYGON ((181.0058 88.30096, 181.0058 88.80096...
# 236744  cell_723_323  POLYGON ((181.0058 88.80096, 181.0058 89.30096...
# 236745  cell_723_324  POLYGON ((181.0058 89.30096, 181.0058 89.80096...
# 236746  cell_723_325  POLYGON ((181.0058 89.80096, 181.0058 90.30096...
# 236747  cell_723_326  POLYGON ((181.0058 90.30096, 181.0058 90.80096...
#
#         lon_center  lat_center  mp_mean_concentration  mp_max_concentration  \
# 0        -180.7442   -72.44904                    NaN                   NaN
# 1        -180.7442   -71.94904                    NaN                   NaN
# 2        -180.7442   -71.44904                    NaN                   NaN
# 3        -180.7442   -70.94904                    NaN                   NaN
# 4        -180.7442   -70.44904                    NaN                   NaN
# ...            ...         ...                    ...                   ...
# 236743    180.7558    88.55096                    NaN                   NaN
# 236744    180.7558    89.05096                    NaN                   NaN
# 236745    180.7558    89.55096                    NaN                   NaN
# 236746    180.7558    90.05096                    NaN                   NaN
# 236747    180.7558    90.55096                    NaN                   NaN
#
#         mp_count  iucn_species_count  iucn_vulnerability_index  \
# 0            NaN                 NaN                       NaN
# 1            NaN                 NaN                       NaN
# 2            NaN                 NaN                       NaN
# 3            NaN                 NaN                       NaN
# 4            NaN                 NaN                       NaN
# ...          ...                 ...                       ...
# 236743       NaN                 NaN                       NaN
# 236744       NaN                 NaN                       NaN
# 236745       NaN                 NaN                       NaN
# 236746       NaN                 NaN                       NaN
# 236747       NaN                 NaN                       NaN
#
#         mean_particle_size  small_particle_ratio
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 236743                 NaN                   NaN
# 236744                 NaN                   NaN
# 236745                 NaN                   NaN
# 236746                 NaN                   NaN
# 236747                 NaN                   NaN
#
# [236748 rows x 11 columns]

# %%
grid.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 236748 entries, 0 to 236747
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   grid_id                   236748 non-null  object
#  1   geometry                  236748 non-null  geometry
#  2   lon_center                236748 non-null  float64
#  3   lat_center                236748 non-null  float64
#  4   mp_mean_concentration     5454 non-null    float64
#  5   mp_max_concentration      5454 non-null    float64
#  6   mp_count                  5652 non-null    float64
#  7   iucn_species_count        5755 non-null    float64
#  8   iucn_vulnerability_index  5755 non-null    float64
#  9   mean_particle_size        74 non-null      float64
#  10  small_particle_ratio      74 non-null      float64
# dtypes: float64(9), geometry(1), object(1)
# memory usage: 19.9+ MB

# %% [markdown]
# # Intento 2

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import box

# %%
# pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.options.display.float_format = '{:.2f}'.format

# %%
# EXPOSICIÓN A MICROPLÁSTICOS

noaa = gpd.read_file("../data/GeoDataFrame/gdf_microplastics.gpkg")
noaa = noaa.to_crs("EPSG:4326")
noaa
# Out:
#        microplastics_measurement              unit concentration_class_range  \
# 0                           0.00         pieces/m3                  0-0.0005
# 1                           0.00         pieces/m3              0.0005-0.005
# 2                           0.00         pieces/m3              0.0005-0.005
# 3                           0.00         pieces/m3                  0-0.0005
# 4                           0.00         pieces/m3                  0-0.0005
# ...                          ...               ...                       ...
# 19317                     188.30  pieces kg-1 d.w.                   150-200
# 19318                     155.27  pieces kg-1 d.w.                   150-200
# 19319                      58.07  pieces kg-1 d.w.                    20-150
# 19320                     210.00  pieces kg-1 d.w.                      >200
# 19321                     208.33  pieces kg-1 d.w.                      >200
#
#        mesh_size_mm   lat    lon                geometry
# 0              0.34 45.28 -60.29    POINT (-60.29 45.28)
# 1              0.34 40.93 -70.65    POINT (-70.65 40.93)
# 2              0.34 40.93 -70.65    POINT (-70.65 40.93)
# 3              0.34 40.30 -69.77     POINT (-69.77 40.3)
# 4              0.34 39.88 -67.15    POINT (-67.15 39.88)
# ...             ...   ...    ...                     ...
# 19317          0.00 -5.93  39.36  POINT (39.36 -5.93333)
# 19318          0.00 -5.50  39.12      POINT (39.12 -5.5)
# 19319          0.00 -6.45  39.47  POINT (39.46667 -6.45)
# 19320          0.00 -6.32  39.21     POINT (39.21 -6.32)
# 19321          0.00 -6.11  39.15     POINT (39.15 -6.11)
#
# [19322 rows x 7 columns]

# %%
noaa['unit'].value_counts()
# Out:
# unit
# pieces/m3           13726
# pieces/10 mins       5125
# pieces kg-1 d.w.      471
# Name: count, dtype: int64

# %%
noaa_water = noaa[noaa['unit'] == 'pieces/m3']
noaa_sediment = noaa[noaa['unit'] == 'pieces kg-1 d.w.']
noaa_time = noaa[noaa['unit'] == 'pieces/10 mins']

# %%
# CREAR GRILLA (La grilla se define por el dataset que mide la EXPOSICIÓN.)

GRID_SIZE = 0.5  # grados
minx, miny, maxx, maxy = noaa.total_bounds

xs = np.arange(minx, maxx, GRID_SIZE)
ys = np.arange(miny, maxy, GRID_SIZE)

cells = []
ids = []

for i, x in enumerate(xs):
    for j, y in enumerate(ys):
        cells.append(box(x, y, x+GRID_SIZE, y+GRID_SIZE))
        ids.append(f"cell_{i}_{j}")

grid = gpd.GeoDataFrame(
    {"grid_id": ids},
    geometry=cells,
    crs="EPSG:4326"
)
grid
# Out:
#              grid_id                                           geometry
# 0           cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...
# 1           cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...
# 2           cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...
# 3           cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...
# 4           cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...
# ...              ...                                                ...
# 232555  cell_719_318  POLYGON ((180.0058 87.30096, 180.0058 87.80096...
# 232556  cell_719_319  POLYGON ((180.0058 87.80096, 180.0058 88.30096...
# 232557  cell_719_320  POLYGON ((180.0058 88.30096, 180.0058 88.80096...
# 232558  cell_719_321  POLYGON ((180.0058 88.80096, 180.0058 89.30096...
# 232559  cell_719_322  POLYGON ((180.0058 89.30096, 180.0058 89.80096...
#
# [232560 rows x 2 columns]

# %%
grid
# Out:
#              grid_id                                           geometry
# 0           cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...
# 1           cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...
# 2           cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...
# 3           cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...
# 4           cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...
# ...              ...                                                ...
# 232555  cell_719_318  POLYGON ((180.0058 87.30096, 180.0058 87.80096...
# 232556  cell_719_319  POLYGON ((180.0058 87.80096, 180.0058 88.30096...
# 232557  cell_719_320  POLYGON ((180.0058 88.30096, 180.0058 88.80096...
# 232558  cell_719_321  POLYGON ((180.0058 88.80096, 180.0058 89.30096...
# 232559  cell_719_322  POLYGON ((180.0058 89.30096, 180.0058 89.80096...
#
# [232560 rows x 2 columns]

# %%
# ASIGNAR PUNTOS DE NOAA A CELDAS DE GRID

noaa_in_grid = gpd.sjoin(noaa_water, grid, predicate="within")
noaa_in_grid
# Out:
#        microplastics_measurement       unit concentration_class_range  \
# 0                           0.00  pieces/m3                  0-0.0005
# 1                           0.00  pieces/m3              0.0005-0.005
# 2                           0.00  pieces/m3              0.0005-0.005
# 3                           0.00  pieces/m3                  0-0.0005
# 4                           0.00  pieces/m3                  0-0.0005
# ...                          ...        ...                       ...
# 19300                       0.01  pieces/m3                   0.005-1
# 19301                       0.01  pieces/m3                   0.005-1
# 19302                       0.00  pieces/m3                  0-0.0005
# 19303                       0.00  pieces/m3              0.0005-0.005
# 19304                       0.00  pieces/m3              0.0005-0.005
#
#        mesh_size_mm    lat    lon                   geometry  index_right  \
# 0              0.34  45.28 -60.29       POINT (-60.29 45.28)        77430
# 1              0.34  40.93 -70.65       POINT (-70.65 40.93)        70639
# 2              0.34  40.93 -70.65       POINT (-70.65 40.93)        70639
# 3              0.34  40.30 -69.77        POINT (-69.77 40.3)        71283
# 4              0.34  39.88 -67.15       POINT (-67.15 39.88)        72898
# ...             ...    ...    ...                        ...          ...
# 19300          0.00 -18.26 178.07  POINT (178.0695 -18.2603)       231374
# 19301          0.00 -17.80 178.72  POINT (178.7219 -17.8049)       231698
# 19302          0.00 -17.80 178.72   POINT (178.721 -17.8049)       231698
# 19303          0.00 -17.80 178.73   POINT (178.729 -17.8049)       231698
# 19304          0.00 -17.80 178.72   POINT (178.7218 -17.804)       231698
#
#             grid_id
# 0      cell_239_233
# 1      cell_218_225
# 2      cell_218_225
# 3      cell_220_223
# 4      cell_225_223
# ...             ...
# 19300  cell_716_106
# 19301  cell_717_107
# 19302  cell_717_107
# 19303  cell_717_107
# 19304  cell_717_107
#
# [13724 rows x 9 columns]

# %%
# AGREGAR POR CELDA

noaa_features = (
    noaa_in_grid
    .groupby("grid_id")
    .agg(
        mp_pieces_m3=("microplastics_measurement", "max")
    )
    .reset_index()
)

noaa_features
# Out:
#           grid_id  mp_pieces_m3
# 0      cell_0_184          0.44
# 1      cell_0_211          1.52
# 2      cell_0_212          0.15
# 3      cell_0_213          0.91
# 4      cell_0_214          0.65
# ...           ...           ...
# 5402  cell_99_222          0.25
# 5403  cell_99_223          0.94
# 5404  cell_99_224          0.24
# 5405  cell_99_227          0.58
# 5406   cell_9_105          0.01
#
# [5407 rows x 2 columns]

# %%
grid = grid.merge(noaa_features, on="grid_id", how="left")
grid
# Out:
#              grid_id                                           geometry  \
# 0           cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...
# 1           cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...
# 2           cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...
# 3           cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...
# 4           cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...
# ...              ...                                                ...
# 232555  cell_719_318  POLYGON ((180.0058 87.30096, 180.0058 87.80096...
# 232556  cell_719_319  POLYGON ((180.0058 87.80096, 180.0058 88.30096...
# 232557  cell_719_320  POLYGON ((180.0058 88.30096, 180.0058 88.80096...
# 232558  cell_719_321  POLYGON ((180.0058 88.80096, 180.0058 89.30096...
# 232559  cell_719_322  POLYGON ((180.0058 89.30096, 180.0058 89.80096...
#
#         mp_pieces_m3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 232555           NaN
# 232556           NaN
# 232557           NaN
# 232558           NaN
# 232559           NaN
#
# [232560 rows x 3 columns]

# %%
tomex = pd.read_csv("../data/Raw/ToMEx_sp_ml.csv")
tomex
# Out:
#                             DOI                 Authors  Year  \
# 0            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 1            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 2            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 3            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# 4            10.7717/peerj.4601  Aljaibachi & Callaghan  2018
# ...                         ...                     ...   ...
# 3898  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3899  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3900  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3901  10.1016/j.fsi.2021.04.014                  Zwollo  2021
# 3902  10.1016/j.fsi.2021.04.014                  Zwollo  2021
#
#                   Species Organism Group Environment    Life Stage  \
# 0           Daphnia magna      Crustacea  Freshwater         adult
# 1           Daphnia magna      Crustacea  Freshwater         adult
# 2           Daphnia magna      Crustacea  Freshwater         adult
# 3           Daphnia magna      Crustacea  Freshwater         adult
# 4           Daphnia magna      Crustacea  Freshwater         early
# ...                   ...            ...         ...           ...
# 3898  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3899  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3900  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3901  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
# 3902  Oncorhynchus mykiss           Fish  Freshwater  Not Reported
#
#      In vitro/in vivo           Sex  Estimated Body Length (cm)  \
# 0             In Vivo  Not Reported                        0.50
# 1             In Vivo  Not Reported                        0.50
# 2             In Vivo  Not Reported                        0.50
# 3             In Vivo  Not Reported                        0.50
# 4             In Vivo  Not Reported                        0.08
# ...               ...           ...                         ...
# 3898         In Vitro  Not Reported                         NaN
# 3899         In Vitro  Not Reported                         NaN
# 3900         In Vitro  Not Reported                         NaN
# 3901         In Vitro  Not Reported                         NaN
# 3902         In Vitro  Not Reported                         NaN
#
#       Estimated Maximum Ingestible Size (mm) Experiment Type Exposure Route  \
# 0                                       0.34   Particle Only          water
# 1                                       0.34   Particle Only          water
# 2                                       0.34   Particle Only          water
# 3                                       0.34   Particle Only          water
# 4                                       0.06   Particle Only          water
# ...                                      ...             ...            ...
# 3898                                     NaN   Particle Only          water
# 3899                                     NaN   Particle Only          water
# 3900                                     NaN   Particle Only          water
# 3901                                     NaN   Particle Only          water
# 3902                                     NaN   Particle Only          water
#
#      Particle Mix? Negative Control Reference Particle     Exposure Media  \
# 0               No                Y                  N  artificial_medium
# 1               No                Y                  N  artificial_medium
# 2               No                Y                  N  artificial_medium
# 3               No                Y                  N  artificial_medium
# 4               No                Y                  N  artificial_medium
# ...            ...              ...                ...                ...
# 3898            No              Yes                 No  artificial_medium
# 3899            No              Yes                 No  artificial_medium
# 3900            No              Yes                 No  artificial_medium
# 3901            No              Yes                 No  artificial_medium
# 3902            No              Yes                 No  artificial_medium
#
#            Solvent     Detergent  pH  Salinity (ppt)  Temperature (Avg)  \
# 0     Not Reported  Not Reported NaN             NaN              20.00
# 1     Not Reported  Not Reported NaN             NaN              20.00
# 2     Not Reported  Not Reported NaN             NaN              20.00
# 3     Not Reported  Not Reported NaN             NaN              20.00
# 4     Not Reported  Not Reported NaN             NaN              20.00
# ...            ...           ...  ..             ...                ...
# 3898          DMSO  Not Reported NaN             NaN              18.00
# 3899          DMSO  Not Reported NaN             NaN              18.00
# 3900          DMSO  Not Reported NaN             NaN              18.00
# 3901          DMSO  Not Reported NaN             NaN              18.00
# 3902          DMSO  Not Reported NaN             NaN              18.00
#
#       Temperature (Min) Temperature (Max)  Exposure Duration (days)  \
# 0                   NaN               NaN                     21.00
# 1                   NaN               NaN                     21.00
# 2                   NaN               NaN                     21.00
# 3                   NaN               NaN                     21.00
# 4                   NaN               NaN                     21.00
# ...                 ...               ...                       ...
# 3898                NaN               NaN                      3.00
# 3899                NaN               NaN                      3.00
# 3900                NaN               NaN                      3.00
# 3901                NaN               NaN                      3.00
# 3902                NaN               NaN                      3.00
#
#       Recovery (Days) Acute/Chronic  Number of Doses  Replicates  \
# 0                 NaN       Chronic                2        8.00
# 1                 NaN       Chronic                2        8.00
# 2                 NaN       Chronic                2        8.00
# 3                 NaN       Chronic                2        8.00
# 4                 NaN       Chronic                2        8.00
# ...               ...           ...              ...         ...
# 3898              NaN         Acute                5        1.00
# 3899              NaN         Acute                5        1.00
# 3900              NaN         Acute                5        1.00
# 3901              NaN         Acute                5        1.00
# 3902              NaN         Acute                5        1.00
#
#         Sample Size  Dosing Frequency Chemicals Added  \
# 0                 1              2.00    Not Reported
# 1                 1              2.00    Not Reported
# 2                 1              2.00    Not Reported
# 3                 1              2.00    Not Reported
# 4                 1              2.00    Not Reported
# ...             ...               ...             ...
# 3898  10^7 cells/mL              0.00    Not Reported
# 3899  10^7 cells/mL              0.00    Not Reported
# 3900  10^7 cells/mL              0.00    Not Reported
# 3901  10^7 cells/mL              0.00    Not Reported
# 3902  10^7 cells/mL              0.00    Not Reported
#
#       Added Chemical Dose (nominal)  Added Chemical Dose (measured)  \
# 0                                 0                             NaN
# 1                                 0                             NaN
# 2                                 0                             NaN
# 3                                 0                             NaN
# 4                                 0                             NaN
# ...                             ...                             ...
# 3898                              0                             NaN
# 3899                              0                             NaN
# 3900                              0                             NaN
# 3901                              0                             NaN
# 3902                              0                             NaN
#
#       Plotted Dose Values  Unaligned Dose Values   Dose Metric  Alignment  \
# 0                  316.04                 316.04  Particles/mL  Unaligned
# 1                 2523.74                2523.74  Particles/mL  Unaligned
# 2                  316.04                 316.04  Particles/mL  Unaligned
# 3                 2523.74                2523.74  Particles/mL  Unaligned
# 4                  316.04                 316.04  Particles/mL  Unaligned
# ...                   ...                    ...           ...        ...
# 3898                 4.05                   4.05  Particles/mL  Unaligned
# 3899                40.49                  40.49  Particles/mL  Unaligned
# 3900               404.91                 404.91  Particles/mL  Unaligned
# 3901              4049.12                4049.12  Particles/mL  Unaligned
# 3902             40491.16               40491.16  Particles/mL  Unaligned
#
#      Effect     Direction Broad Endpoint Category Specific Endpoint Category  \
# 0       Yes      increase                 Fitness                  Mortality
# 1       Yes      increase                 Fitness                  Mortality
# 2        No  Not Reported                 Fitness               Reproduction
# 3        No  Not Reported                 Fitness               Reproduction
# 4       Yes      increase                 Fitness                  Mortality
# ...     ...           ...                     ...                        ...
# 3898    Yes      decrease                  Immune               Immune Cells
# 3899    Yes      decrease                  Immune               Immune Cells
# 3900    Yes      decrease                  Immune               Immune Cells
# 3901    Yes      decrease                  Immune               Immune Cells
# 3902    Yes      decrease                  Immune               Immune Cells
#
#                                 Endpoint Level of Biological Organization  \
# 0                              Mortality                         Organism
# 1                              Mortality                         Organism
# 2                    Number of Offspring                         Organism
# 3                    Number of Offspring                         Organism
# 4                              Mortality                         Organism
# ...                                  ...                              ...
# 3898  B cell abundance (immature/mature)                             Cell
# 3899  B cell abundance (immature/mature)                             Cell
# 3900  B cell abundance (immature/mature)                             Cell
# 3901  B cell abundance (immature/mature)                             Cell
# 3902  B cell abundance (immature/mature)                             Cell
#
#      Target Cell or Tissue Effect Metric      Polymer   Shape  \
# 0             Not Reported           NaN  Polystyrene  Sphere
# 1             Not Reported           NaN  Polystyrene  Sphere
# 2             Not Reported           NaN  Polystyrene  Sphere
# 3             Not Reported           NaN  Polystyrene  Sphere
# 4             Not Reported           NaN  Polystyrene  Sphere
# ...                    ...           ...          ...     ...
# 3898                B cell          LOEC  Polystyrene  Sphere
# 3899                B cell           NaN  Polystyrene  Sphere
# 3900                B cell           NaN  Polystyrene  Sphere
# 3901                B cell           NaN  Polystyrene  Sphere
# 3902                B cell           NaN  Polystyrene  Sphere
#
#       Density (g/cm^3) Density, reported or estimated Charge  \
# 0                 1.05                       reported    NaN
# 1                 1.05                       reported    NaN
# 2                 1.05                       reported    NaN
# 3                 1.05                       reported    NaN
# 4                 1.05                       reported    NaN
# ...                ...                            ...    ...
# 3898              1.05                       reported    NaN
# 3899              1.05                       reported    NaN
# 3900              1.05                       reported    NaN
# 3901              1.05                       reported    NaN
# 3902              1.05                       reported    NaN
#
#       Zeta Potential (mV) Zeta Potential Media Functional Group  \
# 0                     NaN                  NaN             COOH
# 1                     NaN                  NaN             COOH
# 2                     NaN                  NaN             COOH
# 3                     NaN                  NaN             COOH
# 4                     NaN                  NaN             COOH
# ...                   ...                  ...              ...
# 3898                  NaN                  NaN              NaN
# 3899                  NaN                  NaN              NaN
# 3900                  NaN                  NaN              NaN
# 3901                  NaN                  NaN              NaN
# 3902                  NaN                  NaN              NaN
#
#       Particle Length (μm)  Particle Width (μm) Size Category  \
# 0                     2.00                 2.00   1µm < 100µm
# 1                     2.00                 2.00   1µm < 100µm
# 2                     2.00                 2.00   1µm < 100µm
# 3                     2.00                 2.00   1µm < 100µm
# 4                     2.00                 2.00   1µm < 100µm
# ...                    ...                  ...           ...
# 3898                 16.50                16.50   1µm < 100µm
# 3899                 16.50                16.50   1µm < 100µm
# 3900                 16.50                16.50   1µm < 100µm
# 3901                 16.50                16.50   1µm < 100µm
# 3902                 16.50                16.50   1µm < 100µm
#
#       Particle Surface Area (μm^2)  Particle Volume (μm^3)  \
# 0                            12.57                    4.19
# 1                            12.57                    4.19
# 2                            12.57                    4.19
# 3                            12.57                    4.19
# 4                            12.57                    4.19
# ...                            ...                     ...
# 3898                        855.30                 2352.07
# 3899                        855.30                 2352.07
# 3900                        855.30                 2352.07
# 3901                        855.30                 2352.07
# 3902                        855.30                 2352.07
#
#       Particle Mass (mg) Weathered or Biofouled? Size Validated?  \
# 0                   0.00                      No               N
# 1                   0.00                      No               N
# 2                   0.00                      No               N
# 3                   0.00                      No               N
# 4                   0.00                      No               N
# ...                  ...                     ...             ...
# 3898                0.00                      No             Yes
# 3899                0.00                      No             Yes
# 3900                0.00                      No             Yes
# 3901                0.00                      No             Yes
# 3902                0.00                      No             Yes
#
#      Polymer Validated? Shape Validated Particle Source Sodium Azide Present?  \
# 0                     N               N      commercial                    No
# 1                     N               N      commercial                    No
# 2                     N               N      commercial                    No
# 3                     N               N      commercial                    No
# 4                     N               N      commercial                    No
# ...                 ...             ...             ...                   ...
# 3898                 No              No      commercial                   Yes
# 3899                 No              No      commercial                   Yes
# 3900                 No              No      commercial                   Yes
# 3901                 No              No      commercial                   Yes
# 3902                 No              No      commercial                   Yes
#
#      Screened for Chemical Contamination? Particle Cleaning? Solvent Rinse  \
# 0                                       N        not_cleaned          none
# 1                                       N        not_cleaned          none
# 2                                       N        not_cleaned          none
# 3                                       N        not_cleaned          none
# 4                                       N        not_cleaned          none
# ...                                   ...                ...           ...
# 3898                                   No        not_cleaned          none
# 3899                                   No        not_cleaned          none
# 3900                                   No        not_cleaned          none
# 3901                                   No        not_cleaned          none
# 3902                                   No        not_cleaned          none
#
#      Background Contamination Monitored? Concentration Validated?  \
# 0                                      N                        N
# 1                                      N                        N
# 2                                      N                        N
# 3                                      N                        N
# 4                                      N                        N
# ...                                  ...                      ...
# 3898                                  No                       No
# 3899                                  No                       No
# 3900                                  No                       No
# 3901                                  No                       No
# 3902                                  No                       No
#
#      Particle Behavior Uptake Validated?          Uptake Validation Method  \
# 0        Not Evaluated                 Y  microscopy flourescent particles
# 1        Not Evaluated                 Y  microscopy flourescent particles
# 2        Not Evaluated                 Y  microscopy flourescent particles
# 3        Not Evaluated                 Y  microscopy flourescent particles
# 4        Not Evaluated                 Y  microscopy flourescent particles
# ...                ...               ...                               ...
# 3898              none               Yes                        microscopy
# 3899              none               Yes                        microscopy
# 3900              none               Yes                        microscopy
# 3901              none               Yes                        microscopy
# 3902              none               Yes                        microscopy
#
#      Tissue Distribution Organisms Fed?
# 0                    gut            Yes
# 1                    gut            Yes
# 2                    gut            Yes
# 3                    gut            Yes
# 4                    gut            Yes
# ...                  ...            ...
# 3898     anterior kidney             No
# 3899     anterior kidney             No
# 3900     anterior kidney             No
# 3901     anterior kidney             No
# 3902     anterior kidney             No
#
# [3903 rows x 76 columns]

# %%
eco_effect = tomex[
    tomex["Effect"] == "Yes"
]

# %%
eco_tox_threshold = eco_effect["Unaligned Dose Values"].median()
eco_tox_threshold
# Out:
# np.float64(62.5)

# %%
# Conversion unidades de NOAA
grid["mp_particles_ml"] = grid["mp_pieces_m3"] / 1_000_000

# %%
log_eco_tox_threshold = np.log10(eco_tox_threshold)
log_eco_tox_threshold
# Out:
# np.float64(1.7958800173440752)

# %%
import numpy as np

grid["log_mp_particles_ml"] = np.log10(
    grid["mp_particles_ml"] + 1e-12
)

# %%
grid["log_toxic_pressure"] = (
    grid["log_mp_particles_ml"] - log_eco_tox_threshold
)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

grid["toxic_pressure_scaled"] = scaler.fit_transform(
    grid[["log_toxic_pressure"]]
)

# %%
def pressure_class(x):
    if x > -3:
        return "high"
    elif x > -6:
        return "medium"
    else:
        return "low"

grid["toxic_pressure_class"] = grid["log_toxic_pressure"].apply(pressure_class)
grid.head()
# Out:
#     grid_id                                           geometry  mp_pieces_m3  \
# 0  cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...           NaN
# 1  cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...           NaN
# 2  cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...           NaN
# 3  cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...           NaN
# 4  cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...           NaN
#
#    mp_particles_ml  log_mp_particles_ml  log_toxic_pressure  \
# 0              NaN                  NaN                 NaN
# 1              NaN                  NaN                 NaN
# 2              NaN                  NaN                 NaN
# 3              NaN                  NaN                 NaN
# 4              NaN                  NaN                 NaN
#
#    toxic_pressure_scaled toxic_pressure_class
# 0                    NaN                  low
# 1                    NaN                  low
# 2                    NaN                  low
# 3                    NaN                  low
# 4                    NaN                  low

# %%
grid["eco_toxic_pressure"] = (
    grid["mp_particles_ml"] / eco_tox_threshold
)

grid_with_noaa = grid[grid["mp_pieces_m3"].notna()]
grid_with_noaa
# Out:
#              grid_id                                           geometry  \
# 184       cell_0_184  POLYGON ((-179.4942 20.30096, -179.4942 20.800...
# 211       cell_0_211  POLYGON ((-179.4942 33.80096, -179.4942 34.300...
# 212       cell_0_212  POLYGON ((-179.4942 34.30096, -179.4942 34.800...
# 213       cell_0_213  POLYGON ((-179.4942 34.80096, -179.4942 35.300...
# 214       cell_0_214  POLYGON ((-179.4942 35.30096, -179.4942 35.800...
# ...              ...                                                ...
# 231375  cell_716_107  POLYGON ((178.5058 -18.19904, 178.5058 -17.699...
# 231655   cell_717_64  POLYGON ((179.0058 -39.69904, 179.0058 -39.199...
# 231698  cell_717_107  POLYGON ((179.0058 -18.19904, 179.0058 -17.699...
# 231853  cell_717_262  POLYGON ((179.0058 59.30096, 179.0058 59.80096...
# 232343  cell_719_106  POLYGON ((180.0058 -18.69904, 180.0058 -18.199...
#
#         mp_pieces_m3  mp_particles_ml  log_mp_particles_ml  \
# 184             0.44             0.00                -6.36
# 211             1.52             0.00                -5.82
# 212             0.15             0.00                -6.82
# 213             0.91             0.00                -6.04
# 214             0.65             0.00                -6.19
# ...              ...              ...                  ...
# 231375          0.01             0.00                -8.15
# 231655         89.00             0.00                -4.05
# 231698          0.01             0.00                -8.12
# 231853          0.26             0.00                -6.59
# 232343          0.05             0.00                -7.28
#
#         log_toxic_pressure  toxic_pressure_scaled toxic_pressure_class  \
# 184                  -8.15                   0.47                  low
# 211                  -7.61                   0.52                  low
# 212                  -8.62                   0.44                  low
# 213                  -7.84                   0.50                  low
# 214                  -7.98                   0.49                  low
# ...                    ...                    ...                  ...
# 231375               -9.94                   0.32                  low
# 231655               -5.85                   0.67               medium
# 231698               -9.92                   0.33                  low
# 231853               -8.38                   0.45                  low
# 232343               -9.08                   0.40                  low
#
#         eco_toxic_pressure
# 184                   0.00
# 211                   0.00
# 212                   0.00
# 213                   0.00
# 214                   0.00
# ...                    ...
# 231375                0.00
# 231655                0.00
# 231698                0.00
# 231853                0.00
# 232343                0.00
#
# [5407 rows x 9 columns]

# %%
grid_with_noaa["toxic_pressure_class"].value_counts()
# Out:
# toxic_pressure_class
# low       5284
# medium     114
# high         9
# Name: count, dtype: int64

# %%
iucn = gpd.read_file("../data/GeoDataFrame/gdf_species.gpkg").to_crs("EPSG:4326")
iucn
# Out:
#                   sci_name  presence  origin  seasonal     lon   lat  \
# 0         Hubbsina turneri         1       1         1 -101.48 19.87
# 1         Hubbsina turneri         1       1         1 -101.78 19.83
# 2         Hubbsina turneri         1       1         1 -101.79 19.83
# 3      Ictalurus mexicanus         1       1         1  -99.35 21.98
# 4      Ictalurus mexicanus         1       1         1  -99.30 22.00
# ...                    ...       ...     ...       ...     ...   ...
# 70268  Macrobrachium thysi         1       1         1   -3.00  5.14
# 70269  Macrobrachium thysi         1       1         1   -3.52  5.50
# 70270  Macrobrachium thysi         1       1         1   -3.51  5.49
# 70271  Macrobrachium thysi         1       1         1   -4.12  5.40
# 70272  Macrobrachium thysi         1       1         1   -4.05  5.38
#
#       redlistCategory                    geometry
# 0                  CR   POINT (-101.4795 19.8745)
# 1                  CR   POINT (-101.7773 19.8256)
# 2                  CR   POINT (-101.7876 19.8273)
# 3                  VU  POINT (-99.35417 21.98083)
# 4                  VU            POINT (-99.3 22)
# ...               ...                         ...
# 70268              VU    POINT (-3.00185 5.14407)
# 70269              VU    POINT (-3.52102 5.49955)
# 70270              VU    POINT (-3.51293 5.49003)
# 70271              VU    POINT (-4.12282 5.40212)
# 70272              VU    POINT (-4.05195 5.38445)
#
# [70273 rows x 8 columns]

# %%
iucn_grid = gpd.overlay(iucn, grid, how="intersection")
iucn_grid
# Out:
#                   sci_name  presence  origin  seasonal     lon   lat  \
# 0         Hubbsina turneri         1       1         1 -101.48 19.87
# 1         Hubbsina turneri         1       1         1 -101.78 19.83
# 2         Hubbsina turneri         1       1         1 -101.79 19.83
# 3      Ictalurus mexicanus         1       1         1  -99.35 21.98
# 4      Ictalurus mexicanus         1       1         1  -99.30 22.00
# ...                    ...       ...     ...       ...     ...   ...
# 70271  Macrobrachium thysi         1       1         1   -3.00  5.14
# 70272  Macrobrachium thysi         1       1         1   -3.52  5.50
# 70273  Macrobrachium thysi         1       1         1   -3.51  5.49
# 70274  Macrobrachium thysi         1       1         1   -4.12  5.40
# 70275  Macrobrachium thysi         1       1         1   -4.05  5.38
#
#       redlistCategory       grid_id  mp_pieces_m3  mp_particles_ml  \
# 0                  CR  cell_157_183           NaN              NaN
# 1                  CR  cell_156_183           NaN              NaN
# 2                  CR  cell_156_183           NaN              NaN
# 3                  VU  cell_161_187           NaN              NaN
# 4                  VU  cell_161_187           NaN              NaN
# ...               ...           ...           ...              ...
# 70271              VU  cell_353_153           NaN              NaN
# 70272              VU  cell_352_154           NaN              NaN
# 70273              VU  cell_352_154           NaN              NaN
# 70274              VU  cell_351_154           NaN              NaN
# 70275              VU  cell_351_154           NaN              NaN
#
#        log_mp_particles_ml  log_toxic_pressure  toxic_pressure_scaled  \
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                      NaN                 NaN                    NaN
# ...                    ...                 ...                    ...
# 70271                  NaN                 NaN                    NaN
# 70272                  NaN                 NaN                    NaN
# 70273                  NaN                 NaN                    NaN
# 70274                  NaN                 NaN                    NaN
# 70275                  NaN                 NaN                    NaN
#
#       toxic_pressure_class  eco_toxic_pressure                    geometry
# 0                      low                 NaN   POINT (-101.4795 19.8745)
# 1                      low                 NaN   POINT (-101.7773 19.8256)
# 2                      low                 NaN   POINT (-101.7876 19.8273)
# 3                      low                 NaN  POINT (-99.35417 21.98083)
# 4                      low                 NaN            POINT (-99.3 22)
# ...                    ...                 ...                         ...
# 70271                  low                 NaN    POINT (-3.00185 5.14407)
# 70272                  low                 NaN    POINT (-3.52102 5.49955)
# 70273                  low                 NaN    POINT (-3.51293 5.49003)
# 70274                  low                 NaN    POINT (-4.12282 5.40212)
# 70275                  low                 NaN    POINT (-4.05195 5.38445)
#
# [70276 rows x 16 columns]

# %%
status_map = {"CR":4, "EN":3, "VU":2, "NT":1}

iucn_grid["vuln"] = (
    iucn_grid["redlistCategory"]
    .map(status_map)
    .fillna(0)
)
iucn_grid
# Out:
#                   sci_name  presence  origin  seasonal     lon   lat  \
# 0         Hubbsina turneri         1       1         1 -101.48 19.87
# 1         Hubbsina turneri         1       1         1 -101.78 19.83
# 2         Hubbsina turneri         1       1         1 -101.79 19.83
# 3      Ictalurus mexicanus         1       1         1  -99.35 21.98
# 4      Ictalurus mexicanus         1       1         1  -99.30 22.00
# ...                    ...       ...     ...       ...     ...   ...
# 70271  Macrobrachium thysi         1       1         1   -3.00  5.14
# 70272  Macrobrachium thysi         1       1         1   -3.52  5.50
# 70273  Macrobrachium thysi         1       1         1   -3.51  5.49
# 70274  Macrobrachium thysi         1       1         1   -4.12  5.40
# 70275  Macrobrachium thysi         1       1         1   -4.05  5.38
#
#       redlistCategory       grid_id  mp_pieces_m3  mp_particles_ml  \
# 0                  CR  cell_157_183           NaN              NaN
# 1                  CR  cell_156_183           NaN              NaN
# 2                  CR  cell_156_183           NaN              NaN
# 3                  VU  cell_161_187           NaN              NaN
# 4                  VU  cell_161_187           NaN              NaN
# ...               ...           ...           ...              ...
# 70271              VU  cell_353_153           NaN              NaN
# 70272              VU  cell_352_154           NaN              NaN
# 70273              VU  cell_352_154           NaN              NaN
# 70274              VU  cell_351_154           NaN              NaN
# 70275              VU  cell_351_154           NaN              NaN
#
#        log_mp_particles_ml  log_toxic_pressure  toxic_pressure_scaled  \
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2                      NaN                 NaN                    NaN
# 3                      NaN                 NaN                    NaN
# 4                      NaN                 NaN                    NaN
# ...                    ...                 ...                    ...
# 70271                  NaN                 NaN                    NaN
# 70272                  NaN                 NaN                    NaN
# 70273                  NaN                 NaN                    NaN
# 70274                  NaN                 NaN                    NaN
# 70275                  NaN                 NaN                    NaN
#
#       toxic_pressure_class  eco_toxic_pressure                    geometry  \
# 0                      low                 NaN   POINT (-101.4795 19.8745)
# 1                      low                 NaN   POINT (-101.7773 19.8256)
# 2                      low                 NaN   POINT (-101.7876 19.8273)
# 3                      low                 NaN  POINT (-99.35417 21.98083)
# 4                      low                 NaN            POINT (-99.3 22)
# ...                    ...                 ...                         ...
# 70271                  low                 NaN    POINT (-3.00185 5.14407)
# 70272                  low                 NaN    POINT (-3.52102 5.49955)
# 70273                  low                 NaN    POINT (-3.51293 5.49003)
# 70274                  low                 NaN    POINT (-4.12282 5.40212)
# 70275                  low                 NaN    POINT (-4.05195 5.38445)
#
#        vuln
# 0         4
# 1         4
# 2         4
# 3         2
# 4         2
# ...     ...
# 70271     2
# 70272     2
# 70273     2
# 70274     2
# 70275     2
#
# [70276 rows x 17 columns]

# %%
iucn_features = (
    iucn_grid
    .groupby("grid_id")
    .agg(
        vuln_index=("vuln", "mean")
    )
    .reset_index()
)
iucn_features
# Out:
#            grid_id  vuln_index
# 0       cell_0_108        4.00
# 1       cell_0_201        1.00
# 2        cell_0_54        1.00
# 3     cell_107_253        3.00
# 4      cell_10_103        3.00
# ...            ...         ...
# 5750   cell_77_107        2.00
# 5751    cell_90_97        2.00
# 5752    cell_9_100        2.00
# 5753    cell_9_101        3.00
# 5754     cell_9_54        1.00
#
# [5755 rows x 2 columns]

# %%
grid = grid.merge(iucn_features, on="grid_id", how="left")
grid
# Out:
#              grid_id                                           geometry  \
# 0           cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...
# 1           cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...
# 2           cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...
# 3           cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...
# 4           cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...
# ...              ...                                                ...
# 232555  cell_719_318  POLYGON ((180.0058 87.30096, 180.0058 87.80096...
# 232556  cell_719_319  POLYGON ((180.0058 87.80096, 180.0058 88.30096...
# 232557  cell_719_320  POLYGON ((180.0058 88.30096, 180.0058 88.80096...
# 232558  cell_719_321  POLYGON ((180.0058 88.80096, 180.0058 89.30096...
# 232559  cell_719_322  POLYGON ((180.0058 89.30096, 180.0058 89.80096...
#
#         mp_pieces_m3  mp_particles_ml  log_mp_particles_ml  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
# 2                NaN              NaN                  NaN
# 3                NaN              NaN                  NaN
# 4                NaN              NaN                  NaN
# ...              ...              ...                  ...
# 232555           NaN              NaN                  NaN
# 232556           NaN              NaN                  NaN
# 232557           NaN              NaN                  NaN
# 232558           NaN              NaN                  NaN
# 232559           NaN              NaN                  NaN
#
#         log_toxic_pressure  toxic_pressure_scaled toxic_pressure_class  \
# 0                      NaN                    NaN                  low
# 1                      NaN                    NaN                  low
# 2                      NaN                    NaN                  low
# 3                      NaN                    NaN                  low
# 4                      NaN                    NaN                  low
# ...                    ...                    ...                  ...
# 232555                 NaN                    NaN                  low
# 232556                 NaN                    NaN                  low
# 232557                 NaN                    NaN                  low
# 232558                 NaN                    NaN                  low
# 232559                 NaN                    NaN                  low
#
#         eco_toxic_pressure  vuln_index
# 0                      NaN         NaN
# 1                      NaN         NaN
# 2                      NaN         NaN
# 3                      NaN         NaN
# 4                      NaN         NaN
# ...                    ...         ...
# 232555                 NaN         NaN
# 232556                 NaN         NaN
# 232557                 NaN         NaN
# 232558                 NaN         NaN
# 232559                 NaN         NaN
#
# [232560 rows x 10 columns]

# %%
grid["eco_risk_score"] = (
    grid["toxic_pressure_scaled"] *
    grid["vuln_index"]
)
grid
# Out:
#              grid_id                                           geometry  \
# 0           cell_0_0  POLYGON ((-179.4942 -71.69904, -179.4942 -71.1...
# 1           cell_0_1  POLYGON ((-179.4942 -71.19904, -179.4942 -70.6...
# 2           cell_0_2  POLYGON ((-179.4942 -70.69904, -179.4942 -70.1...
# 3           cell_0_3  POLYGON ((-179.4942 -70.19904, -179.4942 -69.6...
# 4           cell_0_4  POLYGON ((-179.4942 -69.69904, -179.4942 -69.1...
# ...              ...                                                ...
# 232555  cell_719_318  POLYGON ((180.0058 87.30096, 180.0058 87.80096...
# 232556  cell_719_319  POLYGON ((180.0058 87.80096, 180.0058 88.30096...
# 232557  cell_719_320  POLYGON ((180.0058 88.30096, 180.0058 88.80096...
# 232558  cell_719_321  POLYGON ((180.0058 88.80096, 180.0058 89.30096...
# 232559  cell_719_322  POLYGON ((180.0058 89.30096, 180.0058 89.80096...
#
#         mp_pieces_m3  mp_particles_ml  log_mp_particles_ml  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
# 2                NaN              NaN                  NaN
# 3                NaN              NaN                  NaN
# 4                NaN              NaN                  NaN
# ...              ...              ...                  ...
# 232555           NaN              NaN                  NaN
# 232556           NaN              NaN                  NaN
# 232557           NaN              NaN                  NaN
# 232558           NaN              NaN                  NaN
# 232559           NaN              NaN                  NaN
#
#         log_toxic_pressure  toxic_pressure_scaled toxic_pressure_class  \
# 0                      NaN                    NaN                  low
# 1                      NaN                    NaN                  low
# 2                      NaN                    NaN                  low
# 3                      NaN                    NaN                  low
# 4                      NaN                    NaN                  low
# ...                    ...                    ...                  ...
# 232555                 NaN                    NaN                  low
# 232556                 NaN                    NaN                  low
# 232557                 NaN                    NaN                  low
# 232558                 NaN                    NaN                  low
# 232559                 NaN                    NaN                  low
#
#         eco_toxic_pressure  vuln_index  eco_risk_score
# 0                      NaN         NaN             NaN
# 1                      NaN         NaN             NaN
# 2                      NaN         NaN             NaN
# 3                      NaN         NaN             NaN
# 4                      NaN         NaN             NaN
# ...                    ...         ...             ...
# 232555                 NaN         NaN             NaN
# 232556                 NaN         NaN             NaN
# 232557                 NaN         NaN             NaN
# 232558                 NaN         NaN             NaN
# 232559                 NaN         NaN             NaN
#
# [232560 rows x 11 columns]

# %%
grid.describe()
# Out:
#        mp_pieces_m3  mp_particles_ml  log_mp_particles_ml  log_toxic_pressure  \
# count       5407.00          5407.00              5407.00             5407.00
# mean         410.55             0.00                -7.74               -9.54
# std        12457.77             0.01                 2.08                2.08
# min            0.00             0.00               -12.00              -13.80
# 25%            0.00             0.00                -8.33              -10.13
# 50%            0.03             0.00                -7.49               -9.29
# 75%            0.33             0.00                -6.48               -8.27
# max       800000.00             0.80                -0.10               -1.89
#
#        toxic_pressure_scaled  eco_toxic_pressure  vuln_index  eco_risk_score
# count                5407.00             5407.00     5755.00          468.00
# mean                    0.36                0.00        1.75            0.70
# std                     0.18                0.00        0.78            0.52
# min                     0.00                0.00        1.00            0.00
# 25%                     0.31                0.00        1.00            0.38
# 50%                     0.38                0.00        1.92            0.61
# 75%                     0.46                0.00        2.00            0.88
# max                     1.00                0.01        4.00            3.65

# %%
grid.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 232560 entries, 0 to 232559
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   grid_id                232560 non-null  object
#  1   geometry               232560 non-null  geometry
#  2   mp_pieces_m3           5407 non-null    float64
#  3   mp_particles_ml        5407 non-null    float64
#  4   log_mp_particles_ml    5407 non-null    float64
#  5   log_toxic_pressure     5407 non-null    float64
#  6   toxic_pressure_scaled  5407 non-null    float64
#  7   toxic_pressure_class   232560 non-null  object
#  8   eco_toxic_pressure     5407 non-null    float64
#  9   vuln_index             5755 non-null    float64
#  10  eco_risk_score         468 non-null     float64
# dtypes: float64(8), geometry(1), object(2)
# memory usage: 19.5+ MB

# %% [markdown]
# # Intento 3. IUCN como base

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
iucn = gpd.read_file("../data/GeoDataFrame/gdf_species.gpkg").to_crs("EPSG:4326")

# %%
iucn = iucn[[
    "sci_name",
    "redlistCategory",
    "geometry"
]].copy()

# %%
iucn["iucn_id"] = iucn.index

# %%
status_map = {"CR":4, "EN":3, "VU":2, "NT":1}

iucn["vuln"] = (
    iucn["redlistCategory"]
    .map(status_map)
    .fillna(0)
)
iucn
# Out:
#                   sci_name redlistCategory                    geometry  \
# 0         Hubbsina turneri              CR   POINT (-101.4795 19.8745)
# 1         Hubbsina turneri              CR   POINT (-101.7773 19.8256)
# 2         Hubbsina turneri              CR   POINT (-101.7876 19.8273)
# 3      Ictalurus mexicanus              VU  POINT (-99.35417 21.98083)
# 4      Ictalurus mexicanus              VU            POINT (-99.3 22)
# ...                    ...             ...                         ...
# 70268  Macrobrachium thysi              VU    POINT (-3.00185 5.14407)
# 70269  Macrobrachium thysi              VU    POINT (-3.52102 5.49955)
# 70270  Macrobrachium thysi              VU    POINT (-3.51293 5.49003)
# 70271  Macrobrachium thysi              VU    POINT (-4.12282 5.40212)
# 70272  Macrobrachium thysi              VU    POINT (-4.05195 5.38445)
#
#        iucn_id  vuln
# 0            0     4
# 1            1     4
# 2            2     4
# 3            3     2
# 4            4     2
# ...        ...   ...
# 70268    70268     2
# 70269    70269     2
# 70270    70270     2
# 70271    70271     2
# 70272    70272     2
#
# [70273 rows x 5 columns]

# %%
noaa = gpd.read_file("../data/GeoDataFrame/gdf_microplastics.gpkg").to_crs("EPSG:4326")

# %%
noaa_valid = noaa[noaa["microplastics_measurement"].notna()].copy()
noaa_nan   = noaa[noaa["microplastics_measurement"].isna()].copy()
noaa_nan
# Out:
#        microplastics_measurement            unit concentration_class_range  \
# 13219                        NaN  pieces/10 mins                      2-40
# 13220                        NaN  pieces/10 mins                    40-200
# 13221                        NaN  pieces/10 mins                    40-200
# 13222                        NaN  pieces/10 mins                      2-40
# 13223                        NaN  pieces/10 mins                       1-2
# ...                          ...             ...                       ...
# 18339                        NaN  pieces/10 mins                      2-40
# 18340                        NaN  pieces/10 mins                      2-40
# 18341                        NaN  pieces/10 mins                    40-200
# 18342                        NaN  pieces/10 mins                      2-40
# 18343                        NaN  pieces/10 mins                      2-40
#
#        mesh_size_mm      lat      lon                  geometry
# 13219           NaN  27.2049 -97.3645  POINT (-97.3645 27.2049)
# 13220           NaN  27.4147 -97.3016  POINT (-97.3016 27.4147)
# 13221           NaN  27.6057 -97.2077  POINT (-97.2077 27.6057)
# 13222           NaN  26.0983 -97.1623  POINT (-97.1623 26.0983)
# 13223           NaN  27.8322 -97.3784  POINT (-97.3784 27.8322)
# ...             ...      ...      ...                       ...
# 18339           NaN  29.3657 -94.8122  POINT (-94.8122 29.3657)
# 18340           NaN  29.3351 -94.7287  POINT (-94.7287 29.3351)
# 18341           NaN  29.3360 -94.7352   POINT (-94.7352 29.336)
# 18342           NaN  32.7114 -96.9773  POINT (-96.9773 32.7114)
# 18343           NaN  29.3359 -94.7354  POINT (-94.7354 29.3359)
#
# [5125 rows x 7 columns]

# %%
noaa = noaa_valid[[
    "microplastics_measurement",
    "geometry"
]].copy()

noaa = noaa.rename(columns={
    "microplastics_measurement": "mp_pieces_m3"
})

# %%
# Asignar microplásticos por cercanía
# Pasar a metros
iucn_m = iucn.to_crs("EPSG:3857")
noaa_m = noaa.to_crs("EPSG:3857")

# %% [markdown]
# index_right  → índice del punto NOAA
#
# mp_pieces_m3 → medición NOAA
#
# dist_m       → distancia (igual para todos los empates)

# %%
iucn_noaa = gpd.sjoin_nearest(
    iucn_m,
    noaa_m,
    how="left",
    distance_col="dist_m"
)
iucn_noaa
# Out:
#                   sci_name redlistCategory                          geometry  \
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 0         Hubbsina turneri              CR  POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR  POINT (-11329797.21 2252382.257)
# ...                    ...             ...                               ...
# 70268  Macrobrachium thysi              VU    POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU    POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU    POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU    POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU     POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m
# 0            0     4        13102    705.218618  244627.454273
# 0            0     4        13101      0.000000  244627.454273
# 0            0     4        13103   1410.437236  244627.454273
# 0            0     4        13104   2115.655853  244627.454273
# 1            1     4        13102    705.218618  237016.489842
# ...        ...   ...          ...           ...            ...
# 70268    70268     2        11468      0.038661  959001.335033
# 70269    70269     2        11468      0.038661  929073.410690
# 70270    70270     2        11468      0.038661  929269.937379
# 70271    70271     2        11468      0.038661  866968.071829
# 70272    70272     2        11468      0.038661  872433.478446
#
# [83621 rows x 8 columns]

# %%
iucn_noaa_clean = (
    iucn_noaa
    .drop_duplicates(subset="iucn_id", keep="first")
)

# %%
iucn_noaa_clean["iucn_id"].value_counts().max()
# Out:
# np.int64(1)

# %%
iucn_noaa = iucn_noaa_clean
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m
# 0            0     4        13102    705.218618  244627.454273
# 1            1     4        13102    705.218618  237016.489842
# 2            2     4        13102    705.218618  237235.709534
# 3            3     2        13033   2115.655853  176956.192726
# 4            4     2        13033   2115.655853  170585.675721
# ...        ...   ...          ...           ...            ...
# 70268    70268     2        11468      0.038661  959001.335033
# 70269    70269     2        11468      0.038661  929073.410690
# 70270    70270     2        11468      0.038661  929269.937379
# 70271    70271     2        11468      0.038661  866968.071829
# 70272    70272     2        11468      0.038661  872433.478446
#
# [70273 rows x 8 columns]

# %%
# Ajustar exposición por distancia
iucn_noaa["distance_km"] = iucn_noaa["dist_m"] / 1000
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# evitar asumir que un muestreo lejano afecta igual.
DECAY_KM = 50  

iucn_noaa["mp_effective_m3"] = (
    iucn_noaa["mp_pieces_m3"] *
    np.exp(- iucn_noaa["distance_km"] / DECAY_KM)
)
iucn_noaa
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13102    705.218618  244627.454273   244.627454
# 1            1     4        13102    705.218618  237016.489842   237.016490
# 2            2     4        13102    705.218618  237235.709534   237.235710
# 3            3     2        13033   2115.655853  176956.192726   176.956193
# 4            4     2        13033   2115.655853  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3
# 0         5.290743e+00
# 1         6.160624e+00
# 2         6.133672e+00
# 3         6.143602e+01
# 4         6.978413e+01
# ...                ...
# 70268     1.809228e-10
# 70269     3.291880e-10
# 70270     3.278966e-10
# 70271     1.139946e-09
# 70272     1.021909e-09
#
# [70273 rows x 10 columns]

# %%
tomex = pd.read_csv("../data/Raw/ToMEx_sp_ml.csv")

# %%
tomex_effect = tomex[tomex["Effect"] == "Yes"]

# %%
eco_tox_threshold = tomex_effect["Unaligned Dose Values"].median()
log_eco_tox_threshold = np.log10(eco_tox_threshold)

# %%
iucn_noaa["mp_particles_ml"] = (
    iucn_noaa["mp_effective_m3"] / 1_000_000
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
iucn_noaa["log_mp_particles_ml"] = np.log10(
    iucn_noaa["mp_particles_ml"] + 1e-12
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
iucn_noaa["log_toxic_pressure"] = (
    iucn_noaa["log_mp_particles_ml"] - log_eco_tox_threshold
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
def pressure_class(x):
    if x > -3:
        return "high"
    elif x > -6:
        return "medium"
    else:
        return "low"

iucn_noaa["toxic_pressure_class"] = iucn_noaa["log_toxic_pressure"].apply(pressure_class)
iucn_noaa.head()
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#               sci_name redlistCategory                           geometry  \
# 0     Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1     Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2     Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3  Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4  Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
#
#    iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0        0     4        13102    705.218618  244627.454273   244.627454
# 1        1     4        13102    705.218618  237016.489842   237.016490
# 2        2     4        13102    705.218618  237235.709534   237.235710
# 3        3     2        13033   2115.655853  176956.192726   176.956193
# 4        4     2        13033   2115.655853  170585.675721   170.585676
#
#    mp_effective_m3  mp_particles_ml  log_mp_particles_ml  log_toxic_pressure  \
# 0         5.290743         0.000005            -5.276483           -7.072363
# 1         6.160624         0.000006            -5.210375           -7.006255
# 2         6.133672         0.000006            -5.212279           -7.008159
# 3        61.436019         0.000061            -4.211577           -6.007457
# 4        69.784130         0.000070            -4.156243           -5.952123
#
#   toxic_pressure_class
# 0                  low
# 1                  low
# 2                  low
# 3                  low
# 4               medium

# %%
iucn_noaa["eco_risk_score"] = (
    iucn_noaa["log_toxic_pressure"] *
    iucn_noaa["vuln"]
)

def risk_class(x):
    if x <= -27.6:
        return "low"
    elif x <= -10.9:
        return "medium"
    else:
        return "high"

iucn_noaa["eco_risk_class"] = iucn_noaa["eco_risk_score"].apply(risk_class)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
iucn_noaa
# Out:
#                   sci_name redlistCategory                           geometry  \
# 0         Hubbsina turneri              CR   POINT (-11296646.266 2258169.64)
# 1         Hubbsina turneri              CR   POINT (-11329797.21 2252382.257)
# 2         Hubbsina turneri              CR  POINT (-11330943.801 2252583.424)
# 3      Ictalurus mexicanus              VU  POINT (-11060055.613 2509223.803)
# 4      Ictalurus mexicanus              VU  POINT (-11054025.436 2511525.235)
# ...                    ...             ...                                ...
# 70268  Macrobrachium thysi              VU     POINT (-334164.413 573406.106)
# 70269  Macrobrachium thysi              VU     POINT (-391958.153 613149.338)
# 70270  Macrobrachium thysi              VU     POINT (-391057.579 612084.684)
# 70271  Macrobrachium thysi              VU     POINT (-458950.223 602254.212)
# 70272  Macrobrachium thysi              VU      POINT (-451061.011 600278.45)
#
#        iucn_id  vuln  index_right  mp_pieces_m3         dist_m  distance_km  \
# 0            0     4        13102    705.218618  244627.454273   244.627454
# 1            1     4        13102    705.218618  237016.489842   237.016490
# 2            2     4        13102    705.218618  237235.709534   237.235710
# 3            3     2        13033   2115.655853  176956.192726   176.956193
# 4            4     2        13033   2115.655853  170585.675721   170.585676
# ...        ...   ...          ...           ...            ...          ...
# 70268    70268     2        11468      0.038661  959001.335033   959.001335
# 70269    70269     2        11468      0.038661  929073.410690   929.073411
# 70270    70270     2        11468      0.038661  929269.937379   929.269937
# 70271    70271     2        11468      0.038661  866968.071829   866.968072
# 70272    70272     2        11468      0.038661  872433.478446   872.433478
#
#        mp_effective_m3  mp_particles_ml  log_mp_particles_ml  \
# 0         5.290743e+00     5.290743e-06            -5.276483
# 1         6.160624e+00     6.160624e-06            -5.210375
# 2         6.133672e+00     6.133672e-06            -5.212279
# 3         6.143602e+01     6.143602e-05            -4.211577
# 4         6.978413e+01     6.978413e-05            -4.156243
# ...                ...              ...                  ...
# 70268     1.809228e-10     1.809228e-16           -11.999921
# 70269     3.291880e-10     3.291880e-16           -11.999857
# 70270     3.278966e-10     3.278966e-16           -11.999858
# 70271     1.139946e-09     1.139946e-15           -11.999505
# 70272     1.021909e-09     1.021909e-15           -11.999556
#
#        log_toxic_pressure toxic_pressure_class  eco_risk_score eco_risk_class
# 0               -7.072363                  low      -28.289453            low
# 1               -7.006255                  low      -28.025021            low
# 2               -7.008159                  low      -28.032637            low
# 3               -6.007457                  low      -12.014914         medium
# 4               -5.952123               medium      -11.904247         medium
# ...                   ...                  ...             ...            ...
# 70268          -13.795801                  low      -27.591603         medium
# 70269          -13.795737                  low      -27.591474         medium
# 70270          -13.795738                  low      -27.591475         medium
# 70271          -13.795385                  low      -27.590770         medium
# 70272          -13.795436                  low      -27.590873         medium
#
# [70273 rows x 16 columns]

# %%
iucn_noaa["eco_risk_score"].describe()
# Out:
# count    70273.000000
# mean       -18.532688
# std         10.087369
# min        -55.183520
# 25%        -27.591760
# 50%        -13.795880
# 75%        -10.943509
# max         -2.628144
# Name: eco_risk_score, dtype: float64

# %%
iucn_noaa["eco_risk_class"].value_counts()
# Out:
# eco_risk_class
# medium    45723
# high      16961
# low        7589
# Name: count, dtype: int64

# %%
iucn_noaa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 70273 entries, 0 to 70272
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sci_name              70273 non-null  object
#  1   redlistCategory       70273 non-null  object
#  2   geometry              70273 non-null  geometry
#  3   iucn_id               70273 non-null  int64
#  4   vuln                  70273 non-null  int64
#  5   index_right           70273 non-null  int64
#  6   mp_pieces_m3          70273 non-null  float64
#  7   dist_m                70273 non-null  float64
#  8   distance_km           70273 non-null  float64
#  9   mp_effective_m3       70273 non-null  float64
#  10  mp_particles_ml       70273 non-null  float64
#  11  log_mp_particles_ml   70273 non-null  float64
#  12  log_toxic_pressure    70273 non-null  float64
#  13  toxic_pressure_class  70273 non-null  object
#  14  eco_risk_score        70273 non-null  float64
#  15  eco_risk_class        70273 non-null  object
# dtypes: float64(8), geometry(1), int64(3), object(4)
# memory usage: 9.1+ MB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 100))

iucn_noaa["eco_risk_index"] = scaler.fit_transform(
    iucn_noaa[["eco_risk_score"]]
)
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/geopandas/geodataframe.py:1969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
def risk_class(x):
    if x <= 20:
        return "very low"
    elif x <= 50:
        return "low"
    elif x <= 80:
        return "medium"
    else:
        return "high"

iucn_noaa["eco_risk_class"] = iucn_noaa["eco_risk_index"].apply(risk_class)
iucn_noaa["eco_risk_class"].value_counts()
# Out:
# eco_risk_class
# medium      33813
# high        29159
# low          6321
# very low      980
# Name: count, dtype: int64

# %%
iucn_noaa.columns
# Out:
# Index(['sci_name', 'redlistCategory', 'geometry', 'iucn_id', 'vuln',
#        'index_right', 'mp_pieces_m3', 'dist_m', 'distance_km',
#        'mp_effective_m3', 'mp_particles_ml', 'log_mp_particles_ml',
#        'log_toxic_pressure', 'toxic_pressure_class', 'eco_risk_score',
#        'eco_risk_class', 'eco_risk_index'],
#       dtype='object')

# %%
new_order = [
    "iucn_id",
    "sci_name",
    "vuln",
    "log_mp_particles_ml",
    "distance_km",
    "log_toxic_pressure",
    "eco_risk_score",
    "eco_risk_index",
    "eco_risk_class",
    "geometry"
]

dataset = iucn_noaa[new_order]

# %%
dataset
# Out:
#        iucn_id             sci_name  vuln  log_mp_particles_ml  distance_km  \
# 0            0     Hubbsina turneri     4            -5.276483   244.627454
# 1            1     Hubbsina turneri     4            -5.210375   237.016490
# 2            2     Hubbsina turneri     4            -5.212279   237.235710
# 3            3  Ictalurus mexicanus     2            -4.211577   176.956193
# 4            4  Ictalurus mexicanus     2            -4.156243   170.585676
# ...        ...                  ...   ...                  ...          ...
# 70268    70268  Macrobrachium thysi     2           -11.999921   959.001335
# 70269    70269  Macrobrachium thysi     2           -11.999857   929.073411
# 70270    70270  Macrobrachium thysi     2           -11.999858   929.269937
# 70271    70271  Macrobrachium thysi     2           -11.999505   866.968072
# 70272    70272  Macrobrachium thysi     2           -11.999556   872.433478
#
#        log_toxic_pressure  eco_risk_score  eco_risk_index eco_risk_class  \
# 0               -7.072363      -28.289453       51.172818         medium
# 1               -7.006255      -28.025021       51.675967         medium
# 2               -7.008159      -28.032637       51.661475         medium
# 3               -6.007457      -12.014914       82.139277           high
# 4               -5.952123      -11.904247       82.349850           high
# ...                   ...             ...             ...            ...
# 70268          -13.795801      -27.591603       52.500656         medium
# 70269          -13.795737      -27.591474       52.500901         medium
# 70270          -13.795738      -27.591475       52.500899         medium
# 70271          -13.795385      -27.590770       52.502240         medium
# 70272          -13.795436      -27.590873       52.502045         medium
#
#                                 geometry
# 0       POINT (-11296646.266 2258169.64)
# 1       POINT (-11329797.21 2252382.257)
# 2      POINT (-11330943.801 2252583.424)
# 3      POINT (-11060055.613 2509223.803)
# 4      POINT (-11054025.436 2511525.235)
# ...                                  ...
# 70268     POINT (-334164.413 573406.106)
# 70269     POINT (-391958.153 613149.338)
# 70270     POINT (-391057.579 612084.684)
# 70271     POINT (-458950.223 602254.212)
# 70272      POINT (-451061.011 600278.45)
#
# [70273 rows x 10 columns]

# %%
# Guardar

dataset.to_file("../data/dataset_unificado.gpkg", layer="ecol_risk", driver="GPKG")
dataset.to_parquet("../data/dataset_unificado.parquet")

# %%
dataset_csv = dataset.copy()
dataset_csv["geometry"] = dataset_csv.geometry.to_wkt()
dataset_csv.to_csv("../data/dataset_unificado_csv.csv", index=False)
# Out:
# /tmp/ipykernel_2591/2035354135.py:2: UserWarning: Geometry column does not contain geometry.
#   dataset_csv["geometry"] = dataset_csv.geometry.to_wkt()
